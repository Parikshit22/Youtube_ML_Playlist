# %%
from IPython.display import Image
Image(filename="img.png")

# %%
a = 10
b = 4
c = (a+b)

# %%
x = 2
if x>5:
    raise ValueError("there is a error")

# %%
try:
    a = 100
    b = 0
    c = int(a)
except ValueError:
    print("valueerror")
except ZeroDivisionError:
    print("zero division")
except Exception as e:
    print(e)
finally:
    print("printed")
# Out:
# printed
